# %%
print(10>=10)
# Out:
# True

# %%
print(10!=10)
# Out:
# False

# %%
print(10>10)
# Out:
# False

# %%
a=11
print(a+b)
print(a-b)
print(a/b)
print(a//b)
print(a%b)
print(a*b)
print(a**b)
# Out:
# 16
# 6
# 2.2
# 2
# 1
# 55
# 161051

# %%
age=24
if(age>18):
    print("you are eligible for voting")
# Out:
# you are eligible for voting

# %%
age=12
if(age>18):
    print("you are eligible for voting")
else:
    print("you are not eligible for voting")
# Out:
# you are not eligible for voting

# %%
a=10
if(a>0):
    print("positive")
elif(a<0):
    print("negative")
else:
    print("zero")
# Out:
# positive

# %%
#write a prgram tofind maximu between two num
a=int(input("Enter the value of a"))
b=int(input("Enter the value of b"))
if(a>b):
    print(a,"is greater than ",b)
else:
    print(b,"is greter than",a)
# Out:
# Enter the value of a 5
# Enter the value of b 6
# 6 is greter than 5

# %%
#write a prgram tofind maximu between three num
a=30
b=20
c=50
if(a>b and a>c):
    print(a,"is greater")
elif(b>c and b>a):
    print(b,"is greater")
elif(c>b and c>a):
    print(c,"is greater")
else:
    print("All are equal")
# Out:
# 50 is greater

# %%
#write a prgram to cheak num is divisible by5 and 11 or not
num=int(input("Enter the number"))
if(num % 5 == 0 and num % 11 == 0):
    print(num," is divisible by 5 and 11 both")
else:
    
    print(num ,"is  not divisible by 5 and 11 both")
# Out:
# Enter the number 55
# 55  is divisible by 5 and 11 both

# %%
#write a prgram to cheak given year is leap  or not
year =int( input("enter the year :"))
if (year % 4 == 0):
    print(year,"is leap year")
else:
    print(year,"is not leap year")
# Out:
# enter the year : 2025
# 2025 is not leap year

# %%
#write a prgram to cheak charcter is Consonant or vowel
char = input("enter a charcter ")
if char in ( 'a','e','i','o','u'):
    print(char,"is vowel")
else:
    print(char,"is consonant")
# Out:
# enter a charcter  v
# v is consonant

# %%
month = int(input("Enter month number (1-12): "))

if month in (1 , 3 , 5, 7 ,8 ,10 , 12):
    print("31 days")
elif month in( 4 ,6 , 9, 11):
    print("30 days")
elif (month == 2):
    print("28 or 29 days (February)")
else:
    print("Invalid month number")
# Out:
# Enter month number (1-12):  2
# 28 or 29 days (February)

# %%
#write a program to cheak profit or loss
costprice= input("Enter the costprice")
sellingprice = input("Enter the sellingprice")
if(sellingprice>costprice):
    print("profit")
elif(sellingprice<costprice):
    print("loss ")
else:
    print("no profit no loss")
# Out:
# Enter the costprice 500
# Enter the sellingprice 600
# profit

# %%
#write a program to cheak the grade of student
marks = int(input("Enter the marks of student"))
totalmarks= int(input("Enter the total marks"))
if(marks>90):
    print("grade A")
elif(marks > 80):
    print("grade B")
elif(marks >70):
    print("Grade C")
elif(marks>60):
    print("Grade D")
elif(marks>40):
    print("Grade E")
else:
    print("Grade fail")
percentage=(marks/totalmarks)*100
print("percentage = ", percentage)
# Out:
# Enter the marks of student 363
# Enter the total marks 600
# grade A
# percentage =  60.5
